# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_2/%20https:/cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/images/IDSNlogo.png" width="300" alt="cognitiveclass.ai logo">
# </center>
#
# <h1 align=center><font size = 5>Assignment: SQL Notebook for Peer Assignment</font></h1>
#
# Estimated time needed: **60** minutes.
#
# ## Introduction
#
# Using this Python notebook you will:
#
# 1.  Understand the Spacex DataSet
# 2.  Load the dataset  into the corresponding table in a Db2 database
# 3.  Execute SQL queries to answer assignment questions

# %% [markdown]
# ## Overview of the DataSet
#
# SpaceX has gained worldwide attention for a series of historic milestones.
#
# It is the only private company ever to return a spacecraft from low-earth orbit, which it first accomplished in December 2010.
# SpaceX advertises Falcon 9 rocket launches on its website with a cost of 62 million dollars wheras other providers cost upward of 165 million dollars each, much of the savings is because Space X can reuse the first stage.
#
# Therefore if we can determine if the first stage will land, we can determine the cost of a launch.
#
# This information can be used if an alternate company wants to bid against SpaceX for a rocket launch.
#
# This dataset includes a record for each payload carried during a SpaceX mission into outer space.

# %% [markdown]
# ### Download the datasets
#
# This assignment requires you to load the spacex dataset.
#
# In many cases the dataset to be analyzed is available as a .CSV (comma separated values) file, perhaps on the internet. Click on the link below to download and save the dataset (.CSV file):
#
# <a href="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_2/data/Spacex.csv?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDS0321ENSkillsNetwork26802033-2022-01-01" target="_blank">Spacex DataSet</a>

# %% [markdown]
# ### Store the dataset in database table
#
# **it is highly recommended to manually load the table using the database console LOAD tool in DB2**.
#
# <img src = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_2/images/spacexload.png">
#
# Now open the Db2 console, open the LOAD tool, Select / Drag the .CSV file for the  dataset, Next create a New Table, and then follow the steps on-screen instructions to load the data. Name the new table as follows:
#
# **SPACEXDATASET**
#
# **Follow these steps while using old DB2 UI which is having Open Console Screen**
#
# **Note:While loading Spacex dataset, ensure that detect datatypes is disabled. Later click on the pencil icon(edit option).**
#
# 1.  Change the Date Format by manually typing DD-MM-YYYY and timestamp format as DD-MM-YYYY HH\:MM:SS.
#
#     Here you should place the cursor at Date field and manually type as DD-MM-YYYY.
#
# 2.  Change the PAYLOAD_MASS\_\_KG\_  datatype  to INTEGER.
#
# <img src = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_2/images/spacexload2.png">

# %% [markdown]
# **Changes to be considered when having DB2 instance with the new UI having Go to UI screen**
#
# *   Refer to this insruction in this <a href="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/Labs_Coursera_V5/labs/Lab%20-%20Sign%20up%20for%20IBM%20Cloud%20-%20Create%20Db2%20service%20instance%20-%20Get%20started%20with%20the%20Db2%20console/instructional-labs.md.html?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDS0321ENSkillsNetwork26802033-2022-01-01">link</a> for viewing  the new  Go to UI screen.
#
# *   Later click on **Data link(below SQL)**  in the Go to UI screen  and click on **Load Data** tab.
#
# *   Later browse for the downloaded spacex file.
#
# <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_2/images/browsefile.png" width="800"/>
#
# *   Once done select the schema andload the file.
#
#  <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_2/images/spacexload3.png" width="800"/>

# %%
# !pip install sqlalchemy==1.3.9
# !pip install ibm_db_sa
# !pip install ipython-sql
# Out:
# Requirement already satisfied: sqlalchemy==1.3.9 in /Users/marcinszyprowski/opt/anaconda3/lib/python3.8/site-packages (1.3.9)
# Collecting ibm_db_sa
#   Using cached ibm_db_sa-0.3.8-py3-none-any.whl (30 kB)
# Collecting ibm-db>=2.0.0
#   Using cached ibm_db-3.1.1.tar.gz (1.1 MB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied: sqlalchemy>=0.7.3 in /Users/marcinszyprowski/opt/anaconda3/lib/python3.8/site-packages (from ibm_db_sa) (1.3.9)
# Building wheels for collected packages: ibm-db
#   Building wheel for ibm-db (PEP 517) ... error
#   ERROR: Command errored out with exit status 1:
#    command: /Users/marcinszyprowski/opt/anaconda3/bin/python /Users/marcinszyprowski/opt/anaconda3/lib/python3.8/site-packages/pip/_vendor/pep517/_in_process.py build_wheel /var/folders/jt/_9ww3dxs067150mvfvx6m_xm0000gp/T/tmp9q694z46
#        cwd: /private/var/folders/jt/_9ww3dxs067150mvfvx6m_xm0000gp/T/pip-install-6md6lnqy/ibm-db_32a99f2e171846699f603e3a71cb7209
#   Complete output (716 lines):
#   Detected 64-bit Python
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build/lib.macosx-10.9-x86_64-cpython-38
#   copying ibm_db_dbi.py -> build/lib.macosx-10.9-x86_64-cpython-38
#   copying testfunctions.py -> build/lib.macosx-10.9-x86_64-cpython-38
#   copying tests.py -> build/lib.macosx-10.9-x86_64-cpython-38
#   creating build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_alltypes.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_111_FieldNumAddCol.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_122_FieldNameDiffCaseColNames.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_065_FilterTableName.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_045_FetchTupleBinaryData_01.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_158_FetchAssocNestedSelects_02.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_251_FreeResult_02.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_221_100PersistentConns.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_200_MultipleRsltsetsUniformColDefs.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_bool_callproc.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_042_FetchTupleMany_02.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_020_RollbackDelete.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_123_FieldNamePos_01.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_197_StatisticsIndexes.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_002_ConnDbUncatalogedConn.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_232_FieldTypePosName.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_InsertRetrieveDateTimeTypeColumn.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_015_InsertDeleteRowCount_01.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_041_FetchTupleMany_01.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_047_FetchTupleMany_06.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_140_BindParamSelectStmt.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_160_FetchBoth.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_050_AutocommitStatus.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_004_ConnWrongUserPwd.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_114_NumericTest_01.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_070_Close.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_024_ForeignKeys.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_031_ResultIndexPosition.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_147_PrepareWithWrongType.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_051_SetAutocommit_01.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_019_selectRowcountPrefetchPrepOpt.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_recreateDB.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_054_CursorType.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_161_FetchBothNestedSelects_01.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_310_ClientInfo.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_003_NumAffectedRows.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_err_executemany.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_265_NoAffectedRows.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_066_TableObjects.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_264_InsertRetrieveBIGINTTypeColumn.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_113_DateTest.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_240_FieldWidthPosName_01.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_044_FetchTupleMany_04.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_261_FetchObjectAccess.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_005_ConnBadUserBadPwd.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_159a_FetchAssocSeveralRows_02.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_211_FieldDisplaySize_02.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_180_StmtErrMsg.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_143_BindParamInsertStmtNoneParam.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_157a_FetchAssocWithoutScrollableCursorErr.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_212_FieldDisplaySize_03.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_warn.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_decimal.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_6528_ScopingProblemBindParam.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_062_Tables_03.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_cursortype.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_152_FetchAssocSelect_03.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_151_FetchAssocSelect_02.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_000_PrepareDb.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_201_MultipleRsltsetsDiffColDefs.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_6561_InsertNULLValues.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_016_InsertDeleteRowCount_02.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_032_ResultIndexName.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_034_FetchAssoc.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_241_FieldWidthPosName_02.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_013_KeysetDrivenCursorSelect02.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_300_ServerInfo.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_033_ResultOutSequenceColumn.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_141_BindParamSelectStmtMultipleParams_01.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_145_BindRetrieveNoneEmptyString.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_053_AttrThruConn.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_043_FetchTupleMany_03.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_124_FieldNamePos_02.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_unicodeTable.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_092_ConnmsgWrongPwd.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_120_FieldName.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_6755_ExtraNULLChar_ResultCLOBCol.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_039_FetchRowIndexPosNested_02.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_trusted_context_connect.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_035_FetchRow_01.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_060_Tables_01.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_createdbNX.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_SPInOutBlob.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_038_FetchRowIndexPosNested_01.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_155_FetchAssocSelect_05.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_014_KeysetDrivenCursorNegativeRow.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_6792_FieldTypeRetStrDatetimeTimestamp.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_116_ConnActive.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_048_FetchTupleBinaryData_02.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_196_InsertRetrieveXMLData_02.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_007_pConnPassingOpts.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_103_NumFieldsSelect_02.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_231_FieldTypeName.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_071_CloseSuccess.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_checkBooleanType.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_090_ConnmsgWrongDbAlias.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_001_ConnDb.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_063_Tables_04.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_017_selectRowcountPrefetchSTMTOpt.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_159_FetchAssocSeveralRows_01.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_195_InsertRetrieveXMLData_01.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_008_ColumnInfo.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_021_CommitDelete.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_230_FieldTypePos.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_trusted_context_pconnect.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_currentschema.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_064_Tables_05.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_046_FetchTupleMany_05.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_booleanInsertSelect.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_142_BindParamSelectStmtMultipleParams_02.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_125_FieldNamePos_03.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_250_FreeResult_01.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_144_BindParamInsertStmtPARAM_FILE.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_156_FetchAssocNestedSelects_01.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_049_InsertNoneParam.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_006_ConnPassingOpts.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_061_Tables_02.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_100_SelectDeleteInsertFieldCount.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_110_FieldNum.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_52949_TestSPIntVarcharXml.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_091_ConnmsgWrongUser.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_133_ExecuteLongInputParams.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_082_ConnWrongPwd.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_025_PrimaryKeys.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_101_InsertDeleteFieldCount.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_03a_ResultNonExistCol.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_alltypesarray.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_080_ConnWrongDbAlias.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_148_CallSPDiffBindPattern_01.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_190_ColumnsTable_01.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_decfloat.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_213_FieldDisplaySize_04.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_150_FetchAssocSelect_01.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_018_selectRowcountPrefetchSetOpt.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_157b_FetchAssocScrollableCursor_02.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_011_DeleteRowCount.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_154_AllFetches.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_030_Result.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_132_ExecuteStatementArrayMultipleParams.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_146_CallSPINAndOUTParams.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_191_ColumnsTable_02.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_execute_many.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_010_UpdateRowCount.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_012_KeysetDrivenCursorSelect01.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_146a_CallSPINAndOUT_Blob_Param.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_115_NumericTest_02.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_220_PersistentConn.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_052_SetAutocommit_02.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_036_FetchRow_02.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_210_FieldDisplaySize_01.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_153_FetchAssocSelect_04.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_037_FetchRowIndexPos.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_131_PrepareExecuteSelectStatementParams.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_022_RollbackInsert.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_162_FetchBothNestedSelects_02.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_260_FetchTupleMany_07.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_SPInOutZero.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_081_ConnWrongUser.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_040_FetchTuple.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_createDropDB.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_311_InsertSelectDeleteNumLiterals.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_121_FieldNameAddCol.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_023_ColumnPrivileges.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_130_PrepExecuteSelectStmt.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_157_FetchAssocScrollableCursor_01.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_112_FieldNumDiffCaseColNames.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_setgetOption.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_102_NumFieldsSelect_01.py -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   creating build/lib.macosx-10.9-x86_64-cpython-38/certs
#   copying certs/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-38/certs
#   creating build/lib.macosx-10.9-x86_64-cpython-38/clidriver
#   copying clidriver/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver
#   running egg_info
#   writing ibm_db.egg-info/PKG-INFO
#   writing dependency_links to ibm_db.egg-info/dependency_links.txt
#   writing top-level names to ibm_db.egg-info/top_level.txt
#   reading manifest file 'ibm_db.egg-info/SOURCES.txt'
#   reading manifest template 'MANIFEST.in'
#   warning: no files found matching '*' under directory 'ibm_db_dlls'
#   warning: no previously-included files found matching 'config.py'
#   adding license file 'LICENSE'
#   writing manifest file 'ibm_db.egg-info/SOURCES.txt'
#   copying ibm_db_tests/pic1.jpg -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/pic1_out.jpg -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/spook.png -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/spook_out.png -> build/lib.macosx-10.9-x86_64-cpython-38/ibm_db_tests
#   copying certs/ibm_certs.pem -> build/lib.macosx-10.9-x86_64-cpython-38/certs
#   copying clidriver/.ftok -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver
#   creating build/lib.macosx-10.9-x86_64-cpython-38/clidriver/bin
#   copying clidriver/bin/db2cli -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/bin
#   copying clidriver/bin/db2diag -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/bin
#   copying clidriver/bin/db2drdat -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/bin
#   copying clidriver/bin/db2dsdcfgfill -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/bin
#   copying clidriver/bin/db2level -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/bin
#   copying clidriver/bin/db2support -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/bin
#   copying clidriver/bin/db2trc -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/bin
#   creating build/lib.macosx-10.9-x86_64-cpython-38/clidriver/bnd
#   copying clidriver/bnd/db2ajgrt.bnd -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/bnd
#   copying clidriver/bnd/db2cli.bnd -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/bnd
#   copying clidriver/bnd/db2cli.lst -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/bnd
#   copying clidriver/bnd/db2clipk.bnd -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/bnd
#   copying clidriver/bnd/db2clist.bnd -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/bnd
#   copying clidriver/bnd/db2spcdb.bnd -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/bnd
#   creating build/lib.macosx-10.9-x86_64-cpython-38/clidriver/cfg
#   copying clidriver/cfg/DigiCertGlobalRootCA.arm -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/cfg
#   copying clidriver/cfg/db2cli.ini.sample -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/cfg
#   copying clidriver/cfg/db2dsdriver.cfg.sample -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/cfg
#   copying clidriver/cfg/db2dsdriver.xsd -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/cfg
#   creating build/lib.macosx-10.9-x86_64-cpython-38/clidriver/cfgcache
#   copying clidriver/cfgcache/conlic.bin -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/cfgcache
#   creating build/lib.macosx-10.9-x86_64-cpython-38/clidriver/conv
#   creating build/lib.macosx-10.9-x86_64-cpython-38/clidriver/conv/alt
#   copying clidriver/conv/alt/04370923.cnv -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/conv/alt
#   copying clidriver/conv/alt/08500923.cnv -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/conv/alt
#   copying clidriver/conv/alt/08501252.cnv -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/conv/alt
#   copying clidriver/conv/alt/08600923.cnv -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/conv/alt
#   copying clidriver/conv/alt/08630923.cnv -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/conv/alt
#   copying clidriver/conv/alt/09230437.cnv -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/conv/alt
#   copying clidriver/conv/alt/09230850.cnv -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/conv/alt
#   copying clidriver/conv/alt/09230860.cnv -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/conv/alt
#   copying clidriver/conv/alt/09231043.cnv -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/conv/alt
#   copying clidriver/conv/alt/09231051.cnv -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/conv/alt
#   copying clidriver/conv/alt/09231114.cnv -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/conv/alt
#   copying clidriver/conv/alt/09231208.cnv -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/conv/alt
#   copying clidriver/conv/alt/09231252.cnv -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/conv/alt
#   copying clidriver/conv/alt/09231275.cnv -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/conv/alt
#   copying clidriver/conv/alt/09241252.cnv -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/conv/alt
#   copying clidriver/conv/alt/09370950.cnv -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/conv/alt
#   copying clidriver/conv/alt/10430923.cnv -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/conv/alt
#   copying clidriver/conv/alt/10510923.cnv -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/conv/alt
#   copying clidriver/conv/alt/11140923.cnv -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/conv/alt
#   copying clidriver/conv/alt/12080923.cnv -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/conv/alt
#   copying clidriver/conv/alt/12520850.cnv -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/conv/alt
#   copying clidriver/conv/alt/12520923.cnv -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/conv/alt
#   copying clidriver/conv/alt/12750923.cnv -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/conv/alt
#   copying clidriver/conv/alt/1388ucs2.cnv -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/conv/alt
#   copying clidriver/conv/alt/IBM00850.ucs -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/conv/alt
#   copying clidriver/conv/alt/IBM00923.ucs -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/conv/alt
#   copying clidriver/conv/alt/IBM01252.ucs -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/conv/alt
#   creating build/lib.macosx-10.9-x86_64-cpython-38/clidriver/conv/ms
#   copying clidriver/conv/ms/0930ucs2.cnv -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/conv/ms
#   copying clidriver/conv/ms/0939ucs2.cnv -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/conv/ms
#   copying clidriver/conv/ms/0943ucs2.cnv -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/conv/ms
#   copying clidriver/conv/ms/0954ucs2.cnv -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/conv/ms
#   copying clidriver/conv/ms/1390ucs2.cnv -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/conv/ms
#   copying clidriver/conv/ms/1399ucs2.cnv -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/conv/ms
#   copying clidriver/conv/ms/5039ucs2.cnv -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/conv/ms
#   copying clidriver/conv/ms/ucs20943.cnv -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/conv/ms
#   creating build/lib.macosx-10.9-x86_64-cpython-38/clidriver/include
#   copying clidriver/include/sql.h -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/include
#   copying clidriver/include/sqlca.h -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/include
#   copying clidriver/include/sqlcli.h -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/include
#   copying clidriver/include/sqlcli1.h -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/include
#   copying clidriver/include/sqlda.h -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/include
#   copying clidriver/include/sqlenv.h -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/include
#   copying clidriver/include/sqlext.h -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/include
#   copying clidriver/include/sqlstate.h -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/include
#   copying clidriver/include/sqlsystm.h -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/include
#   copying clidriver/include/sqltypes.h -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/include
#   copying clidriver/include/sqlucode.h -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/include
#   copying clidriver/include/sqlunx.h -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/include
#   creating build/lib.macosx-10.9-x86_64-cpython-38/clidriver/lib
#   copying clidriver/lib/libDB2xml4c.58.0.dylib -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/lib
#   copying clidriver/lib/libDB2xml4c.58.dylib -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/lib
#   copying clidriver/lib/libDB2xml4c.dylib -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/lib
#   copying clidriver/lib/libdb2.dylib -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/lib
#   copying clidriver/lib/libdb2clixml4c.dylib -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/lib
#   copying clidriver/lib/libgcc_s.1.dylib -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/lib
#   copying clidriver/lib/libstdc++.6.dylib -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/lib
#   creating build/lib.macosx-10.9-x86_64-cpython-38/clidriver/lib/icc
#   copying clidriver/lib/icc/libgsk8acmeidup.dylib -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/lib/icc
#   copying clidriver/lib/icc/libgsk8cms.dylib -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/lib/icc
#   copying clidriver/lib/icc/libgsk8dbfl.dylib -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/lib/icc
#   copying clidriver/lib/icc/libgsk8drld.dylib -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/lib/icc
#   copying clidriver/lib/icc/libgsk8iccs.dylib -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/lib/icc
#   copying clidriver/lib/icc/libgsk8kicc.dylib -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/lib/icc
#   copying clidriver/lib/icc/libgsk8km.dylib -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/lib/icc
#   copying clidriver/lib/icc/libgsk8km2.dylib -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/lib/icc
#   copying clidriver/lib/icc/libgsk8ldap.dylib -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/lib/icc
#   copying clidriver/lib/icc/libgsk8p11.dylib -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/lib/icc
#   copying clidriver/lib/icc/libgsk8ssl.dylib -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/lib/icc
#   copying clidriver/lib/icc/libgsk8sys.dylib -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/lib/icc
#   copying clidriver/lib/icc/libgsk8valn.dylib -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/lib/icc
#   creating build/lib.macosx-10.9-x86_64-cpython-38/clidriver/lib/icc/C
#   creating build/lib.macosx-10.9-x86_64-cpython-38/clidriver/lib/icc/C/icc
#   creating build/lib.macosx-10.9-x86_64-cpython-38/clidriver/lib/icc/C/icc/icclib
#   copying clidriver/lib/icc/C/icc/icclib/ICCSIG.txt -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/lib/icc/C/icc/icclib
#   copying clidriver/lib/icc/C/icc/icclib/libicclib084.dylib -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/lib/icc/C/icc/icclib
#   creating build/lib.macosx-10.9-x86_64-cpython-38/clidriver/lib/icc/N
#   creating build/lib.macosx-10.9-x86_64-cpython-38/clidriver/lib/icc/N/icc
#   creating build/lib.macosx-10.9-x86_64-cpython-38/clidriver/lib/icc/N/icc/icclib
#   copying clidriver/lib/icc/N/icc/icclib/ICCSIG.txt -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/lib/icc/N/icc/icclib
#   copying clidriver/lib/icc/N/icc/icclib/libicclib085.dylib -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/lib/icc/N/icc/icclib
#   creating build/lib.macosx-10.9-x86_64-cpython-38/clidriver/license
#   copying clidriver/license/odbc_REDIST.txt -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/license
#   copying clidriver/license/odbc_notices.txt -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/license
#   creating build/lib.macosx-10.9-x86_64-cpython-38/clidriver/license/UNIX
#   copying clidriver/license/UNIX/odbc_LI_cs -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/license/UNIX
#   copying clidriver/license/UNIX/odbc_LI_de -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/license/UNIX
#   copying clidriver/license/UNIX/odbc_LI_el -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/license/UNIX
#   copying clidriver/license/UNIX/odbc_LI_en -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/license/UNIX
#   copying clidriver/license/UNIX/odbc_LI_es -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/license/UNIX
#   copying clidriver/license/UNIX/odbc_LI_fr -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/license/UNIX
#   copying clidriver/license/UNIX/odbc_LI_in -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/license/UNIX
#   copying clidriver/license/UNIX/odbc_LI_it -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/license/UNIX
#   copying clidriver/license/UNIX/odbc_LI_ja -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/license/UNIX
#   copying clidriver/license/UNIX/odbc_LI_ko -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/license/UNIX
#   copying clidriver/license/UNIX/odbc_LI_lt -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/license/UNIX
#   copying clidriver/license/UNIX/odbc_LI_pl -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/license/UNIX
#   copying clidriver/license/UNIX/odbc_LI_pt -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/license/UNIX
#   copying clidriver/license/UNIX/odbc_LI_ru -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/license/UNIX
#   copying clidriver/license/UNIX/odbc_LI_sl -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/license/UNIX
#   copying clidriver/license/UNIX/odbc_LI_tr -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/license/UNIX
#   copying clidriver/license/UNIX/odbc_LI_zh -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/license/UNIX
#   copying clidriver/license/UNIX/odbc_LI_zh_TW -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/license/UNIX
#   creating build/lib.macosx-10.9-x86_64-cpython-38/clidriver/msg
#   creating build/lib.macosx-10.9-x86_64-cpython-38/clidriver/msg/en_US.iso88591
#   copying clidriver/msg/en_US.iso88591/db2adm.mo -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/msg/en_US.iso88591
#   copying clidriver/msg/en_US.iso88591/db2admh.mo -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/msg/en_US.iso88591
#   copying clidriver/msg/en_US.iso88591/db2caem.mo -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/msg/en_US.iso88591
#   copying clidriver/msg/en_US.iso88591/db2cklog.mo -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/msg/en_US.iso88591
#   copying clidriver/msg/en_US.iso88591/db2cli.mo -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/msg/en_US.iso88591
#   copying clidriver/msg/en_US.iso88591/db2clia1.lst -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/msg/en_US.iso88591
#   copying clidriver/msg/en_US.iso88591/db2clias.lst -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/msg/en_US.iso88591
#   copying clidriver/msg/en_US.iso88591/db2clih.mo -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/msg/en_US.iso88591
#   copying clidriver/msg/en_US.iso88591/db2clit.mo -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/msg/en_US.iso88591
#   copying clidriver/msg/en_US.iso88591/db2clp.mo -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/msg/en_US.iso88591
#   copying clidriver/msg/en_US.iso88591/db2clp2.mo -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/msg/en_US.iso88591
#   copying clidriver/msg/en_US.iso88591/db2diag.mo -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/msg/en_US.iso88591
#   copying clidriver/msg/en_US.iso88591/db2fodc.mo -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/msg/en_US.iso88591
#   copying clidriver/msg/en_US.iso88591/db2sql.mo -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/msg/en_US.iso88591
#   copying clidriver/msg/en_US.iso88591/db2sqlh.mo -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/msg/en_US.iso88591
#   copying clidriver/msg/en_US.iso88591/db2stt.mo -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/msg/en_US.iso88591
#   copying clidriver/msg/en_US.iso88591/db2supp.mo -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/msg/en_US.iso88591
#   creating build/lib.macosx-10.9-x86_64-cpython-38/clidriver/security64
#   creating build/lib.macosx-10.9-x86_64-cpython-38/clidriver/security64/plugin
#   creating build/lib.macosx-10.9-x86_64-cpython-38/clidriver/security64/plugin/IBM
#   creating build/lib.macosx-10.9-x86_64-cpython-38/clidriver/security64/plugin/IBM/client
#   copying clidriver/security64/plugin/IBM/client/IBMIAMauth.dylib -> build/lib.macosx-10.9-x86_64-cpython-38/clidriver/security64/plugin/IBM/client
#   running build_ext
#   building 'ibm_db' extension
#   creating build/temp.macosx-10.9-x86_64-cpython-38
#   gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -I/Users/marcinszyprowski/opt/anaconda3/include -arch x86_64 -I/Users/marcinszyprowski/opt/anaconda3/include -arch x86_64 -Iclidriver/include -I/Users/marcinszyprowski/opt/anaconda3/include/python3.8 -c ibm_db.c -o build/temp.macosx-10.9-x86_64-cpython-38/ibm_db.o
#   xcode-select: note: no developer tools were found at '/Applications/Xcode.app', requesting install. Choose an option in the dialog to download the command line developer tools.
#   /private/var/folders/jt/_9ww3dxs067150mvfvx6m_xm0000gp/T/pip-build-env-lxn9csey/overlay/lib/python3.8/site-packages/setuptools/command/build_py.py:153: SetuptoolsDeprecationWarning:     Installing 'clidriver.bin' as data is deprecated, please list it in `packages`.
#       !!
#
#
#       ############################
#       # Package would be ignored #
#       ############################
#       Python recognizes 'clidriver.bin' as an importable package, however it is
#       included in the distribution as "data".
#       This behavior is likely to change in future versions of setuptools (and
#       therefore is considered deprecated).
#
#       Please make sure that 'clidriver.bin' is included as a package by using
#       setuptools' `packages` configuration field or the proper discovery methods
#       (for example by using `find_namespace_packages(...)`/`find_namespace:`
#       instead of `find_packages(...)`/`find:`).
#
#       You can read more about "package discovery" and "data files" on setuptools
#       documentation page.
#
#
#   !!
#
#     check.warn(importable)
#   /private/var/folders/jt/_9ww3dxs067150mvfvx6m_xm0000gp/T/pip-build-env-lxn9csey/overlay/lib/python3.8/site-packages/setuptools/command/build_py.py:153: SetuptoolsDeprecationWarning:     Installing 'clidriver.bnd' as data is deprecated, please list it in `packages`.
#       !!
#
#
#       ############################
#       # Package would be ignored #
#       ############################
#       Python recognizes 'clidriver.bnd' as an importable package, however it is
#       included in the distribution as "data".
#       This behavior is likely to change in future versions of setuptools (and
#       therefore is considered deprecated).
#
#       Please make sure that 'clidriver.bnd' is included as a package by using
#       setuptools' `packages` configuration field or the proper discovery methods
#       (for example by using `find_namespace_packages(...)`/`find_namespace:`
#       instead of `find_packages(...)`/`find:`).
#
#       You can read more about "package discovery" and "data files" on setuptools
#       documentation page.
#
#
#   !!
#
#     check.warn(importable)
#   /private/var/folders/jt/_9ww3dxs067150mvfvx6m_xm0000gp/T/pip-build-env-lxn9csey/overlay/lib/python3.8/site-packages/setuptools/command/build_py.py:153: SetuptoolsDeprecationWarning:     Installing 'clidriver.cfg' as data is deprecated, please list it in `packages`.
#       !!
#
#
#       ############################
#       # Package would be ignored #
#       ############################
#       Python recognizes 'clidriver.cfg' as an importable package, however it is
#       included in the distribution as "data".
#       This behavior is likely to change in future versions of setuptools (and
#       therefore is considered deprecated).
#
#       Please make sure that 'clidriver.cfg' is included as a package by using
#       setuptools' `packages` configuration field or the proper discovery methods
#       (for example by using `find_namespace_packages(...)`/`find_namespace:`
#       instead of `find_packages(...)`/`find:`).
#
#       You can read more about "package discovery" and "data files" on setuptools
#       documentation page.
#
#
#   !!
#
#     check.warn(importable)
#   /private/var/folders/jt/_9ww3dxs067150mvfvx6m_xm0000gp/T/pip-build-env-lxn9csey/overlay/lib/python3.8/site-packages/setuptools/command/build_py.py:153: SetuptoolsDeprecationWarning:     Installing 'clidriver.cfgcache' as data is deprecated, please list it in `packages`.
#       !!
#
#
#       ############################
#       # Package would be ignored #
#       ############################
#       Python recognizes 'clidriver.cfgcache' as an importable package, however it is
#       included in the distribution as "data".
#       This behavior is likely to change in future versions of setuptools (and
#       therefore is considered deprecated).
#
#       Please make sure that 'clidriver.cfgcache' is included as a package by using
#       setuptools' `packages` configuration field or the proper discovery methods
#       (for example by using `find_namespace_packages(...)`/`find_namespace:`
#       instead of `find_packages(...)`/`find:`).
#
#       You can read more about "package discovery" and "data files" on setuptools
#       documentation page.
#
#
#   !!
#
#     check.warn(importable)
#   /private/var/folders/jt/_9ww3dxs067150mvfvx6m_xm0000gp/T/pip-build-env-lxn9csey/overlay/lib/python3.8/site-packages/setuptools/command/build_py.py:153: SetuptoolsDeprecationWarning:     Installing 'clidriver.conv.alt' as data is deprecated, please list it in `packages`.
#       !!
#
#
#       ############################
#       # Package would be ignored #
#       ############################
#       Python recognizes 'clidriver.conv.alt' as an importable package, however it is
#       included in the distribution as "data".
#       This behavior is likely to change in future versions of setuptools (and
#       therefore is considered deprecated).
#
#       Please make sure that 'clidriver.conv.alt' is included as a package by using
#       setuptools' `packages` configuration field or the proper discovery methods
#       (for example by using `find_namespace_packages(...)`/`find_namespace:`
#       instead of `find_packages(...)`/`find:`).
#
#       You can read more about "package discovery" and "data files" on setuptools
#       documentation page.
#
#
#   !!
#
#     check.warn(importable)
#   /private/var/folders/jt/_9ww3dxs067150mvfvx6m_xm0000gp/T/pip-build-env-lxn9csey/overlay/lib/python3.8/site-packages/setuptools/command/build_py.py:153: SetuptoolsDeprecationWarning:     Installing 'clidriver.conv.ms' as data is deprecated, please list it in `packages`.
#       !!
#
#
#       ############################
#       # Package would be ignored #
#       ############################
#       Python recognizes 'clidriver.conv.ms' as an importable package, however it is
#       included in the distribution as "data".
#       This behavior is likely to change in future versions of setuptools (and
#       therefore is considered deprecated).
#
#       Please make sure that 'clidriver.conv.ms' is included as a package by using
#       setuptools' `packages` configuration field or the proper discovery methods
#       (for example by using `find_namespace_packages(...)`/`find_namespace:`
#       instead of `find_packages(...)`/`find:`).
#
#       You can read more about "package discovery" and "data files" on setuptools
#       documentation page.
#
#
#   !!
#
#     check.warn(importable)
#   /private/var/folders/jt/_9ww3dxs067150mvfvx6m_xm0000gp/T/pip-build-env-lxn9csey/overlay/lib/python3.8/site-packages/setuptools/command/build_py.py:153: SetuptoolsDeprecationWarning:     Installing 'clidriver.include' as data is deprecated, please list it in `packages`.
#       !!
#
#
#       ############################
#       # Package would be ignored #
#       ############################
#       Python recognizes 'clidriver.include' as an importable package, however it is
#       included in the distribution as "data".
#       This behavior is likely to change in future versions of setuptools (and
#       therefore is considered deprecated).
#
#       Please make sure that 'clidriver.include' is included as a package by using
#       setuptools' `packages` configuration field or the proper discovery methods
#       (for example by using `find_namespace_packages(...)`/`find_namespace:`
#       instead of `find_packages(...)`/`find:`).
#
#       You can read more about "package discovery" and "data files" on setuptools
#       documentation page.
#
#
#   !!
#
#     check.warn(importable)
#   /private/var/folders/jt/_9ww3dxs067150mvfvx6m_xm0000gp/T/pip-build-env-lxn9csey/overlay/lib/python3.8/site-packages/setuptools/command/build_py.py:153: SetuptoolsDeprecationWarning:     Installing 'clidriver.lib' as data is deprecated, please list it in `packages`.
#       !!
#
#
#       ############################
#       # Package would be ignored #
#       ############################
#       Python recognizes 'clidriver.lib' as an importable package, however it is
#       included in the distribution as "data".
#       This behavior is likely to change in future versions of setuptools (and
#       therefore is considered deprecated).
#
#       Please make sure that 'clidriver.lib' is included as a package by using
#       setuptools' `packages` configuration field or the proper discovery methods
#       (for example by using `find_namespace_packages(...)`/`find_namespace:`
#       instead of `find_packages(...)`/`find:`).
#
#       You can read more about "package discovery" and "data files" on setuptools
#       documentation page.
#
#
#   !!
#
#     check.warn(importable)
#   /private/var/folders/jt/_9ww3dxs067150mvfvx6m_xm0000gp/T/pip-build-env-lxn9csey/overlay/lib/python3.8/site-packages/setuptools/command/build_py.py:153: SetuptoolsDeprecationWarning:     Installing 'clidriver.lib.icc' as data is deprecated, please list it in `packages`.
#       !!
#
#
#       ############################
#       # Package would be ignored #
#       ############################
#       Python recognizes 'clidriver.lib.icc' as an importable package, however it is
#       included in the distribution as "data".
#       This behavior is likely to change in future versions of setuptools (and
#       therefore is considered deprecated).
#
#       Please make sure that 'clidriver.lib.icc' is included as a package by using
#       setuptools' `packages` configuration field or the proper discovery methods
#       (for example by using `find_namespace_packages(...)`/`find_namespace:`
#       instead of `find_packages(...)`/`find:`).
#
#       You can read more about "package discovery" and "data files" on setuptools
#       documentation page.
#
#
#   !!
#
#     check.warn(importable)
#   /private/var/folders/jt/_9ww3dxs067150mvfvx6m_xm0000gp/T/pip-build-env-lxn9csey/overlay/lib/python3.8/site-packages/setuptools/command/build_py.py:153: SetuptoolsDeprecationWarning:     Installing 'clidriver.lib.icc.C.icc.icclib' as data is deprecated, please list it in `packages`.
#       !!
#
#
#       ############################
#       # Package would be ignored #
#       ############################
#       Python recognizes 'clidriver.lib.icc.C.icc.icclib' as an importable package, however it is
#       included in the distribution as "data".
#       This behavior is likely to change in future versions of setuptools (and
#       therefore is considered deprecated).
#
#       Please make sure that 'clidriver.lib.icc.C.icc.icclib' is included as a package by using
#       setuptools' `packages` configuration field or the proper discovery methods
#       (for example by using `find_namespace_packages(...)`/`find_namespace:`
#       instead of `find_packages(...)`/`find:`).
#
#       You can read more about "package discovery" and "data files" on setuptools
#       documentation page.
#
#
#   !!
#
#     check.warn(importable)
#   /private/var/folders/jt/_9ww3dxs067150mvfvx6m_xm0000gp/T/pip-build-env-lxn9csey/overlay/lib/python3.8/site-packages/setuptools/command/build_py.py:153: SetuptoolsDeprecationWarning:     Installing 'clidriver.lib.icc.N.icc.icclib' as data is deprecated, please list it in `packages`.
#       !!
#
#
#       ############################
#       # Package would be ignored #
#       ############################
#       Python recognizes 'clidriver.lib.icc.N.icc.icclib' as an importable package, however it is
#       included in the distribution as "data".
#       This behavior is likely to change in future versions of setuptools (and
#       therefore is considered deprecated).
#
#       Please make sure that 'clidriver.lib.icc.N.icc.icclib' is included as a package by using
#       setuptools' `packages` configuration field or the proper discovery methods
#       (for example by using `find_namespace_packages(...)`/`find_namespace:`
#       instead of `find_packages(...)`/`find:`).
#
#       You can read more about "package discovery" and "data files" on setuptools
#       documentation page.
#
#
#   !!
#
#     check.warn(importable)
#   /private/var/folders/jt/_9ww3dxs067150mvfvx6m_xm0000gp/T/pip-build-env-lxn9csey/overlay/lib/python3.8/site-packages/setuptools/command/build_py.py:153: SetuptoolsDeprecationWarning:     Installing 'clidriver.license' as data is deprecated, please list it in `packages`.
#       !!
#
#
#       ############################
#       # Package would be ignored #
#       ############################
#       Python recognizes 'clidriver.license' as an importable package, however it is
#       included in the distribution as "data".
#       This behavior is likely to change in future versions of setuptools (and
#       therefore is considered deprecated).
#
#       Please make sure that 'clidriver.license' is included as a package by using
#       setuptools' `packages` configuration field or the proper discovery methods
#       (for example by using `find_namespace_packages(...)`/`find_namespace:`
#       instead of `find_packages(...)`/`find:`).
#
#       You can read more about "package discovery" and "data files" on setuptools
#       documentation page.
#
#
#   !!
#
#     check.warn(importable)
#   /private/var/folders/jt/_9ww3dxs067150mvfvx6m_xm0000gp/T/pip-build-env-lxn9csey/overlay/lib/python3.8/site-packages/setuptools/command/build_py.py:153: SetuptoolsDeprecationWarning:     Installing 'clidriver.license.UNIX' as data is deprecated, please list it in `packages`.
#       !!
#
#
#       ############################
#       # Package would be ignored #
#       ############################
#       Python recognizes 'clidriver.license.UNIX' as an importable package, however it is
#       included in the distribution as "data".
#       This behavior is likely to change in future versions of setuptools (and
#       therefore is considered deprecated).
#
#       Please make sure that 'clidriver.license.UNIX' is included as a package by using
#       setuptools' `packages` configuration field or the proper discovery methods
#       (for example by using `find_namespace_packages(...)`/`find_namespace:`
#       instead of `find_packages(...)`/`find:`).
#
#       You can read more about "package discovery" and "data files" on setuptools
#       documentation page.
#
#
#   !!
#
#     check.warn(importable)
#   /private/var/folders/jt/_9ww3dxs067150mvfvx6m_xm0000gp/T/pip-build-env-lxn9csey/overlay/lib/python3.8/site-packages/setuptools/command/build_py.py:153: SetuptoolsDeprecationWarning:     Installing 'clidriver.msg' as data is deprecated, please list it in `packages`.
#       !!
#
#
#       ############################
#       # Package would be ignored #
#       ############################
#       Python recognizes 'clidriver.msg' as an importable package, however it is
#       included in the distribution as "data".
#       This behavior is likely to change in future versions of setuptools (and
#       therefore is considered deprecated).
#
#       Please make sure that 'clidriver.msg' is included as a package by using
#       setuptools' `packages` configuration field or the proper discovery methods
#       (for example by using `find_namespace_packages(...)`/`find_namespace:`
#       instead of `find_packages(...)`/`find:`).
#
#       You can read more about "package discovery" and "data files" on setuptools
#       documentation page.
#
#
#   !!
#
#     check.warn(importable)
#   /private/var/folders/jt/_9ww3dxs067150mvfvx6m_xm0000gp/T/pip-build-env-lxn9csey/overlay/lib/python3.8/site-packages/setuptools/command/build_py.py:153: SetuptoolsDeprecationWarning:     Installing 'clidriver.security64.plugin.IBM.client' as data is deprecated, please list it in `packages`.
#       !!
#
#
#       ############################
#       # Package would be ignored #
#       ############################
#       Python recognizes 'clidriver.security64.plugin.IBM.client' as an importable package, however it is
#       included in the distribution as "data".
#       This behavior is likely to change in future versions of setuptools (and
#       therefore is considered deprecated).
#
#       Please make sure that 'clidriver.security64.plugin.IBM.client' is included as a package by using
#       setuptools' `packages` configuration field or the proper discovery methods
#       (for example by using `find_namespace_packages(...)`/`find_namespace:`
#       instead of `find_packages(...)`/`find:`).
#
#       You can read more about "package discovery" and "data files" on setuptools
#       documentation page.
#
#
#   !!
#
#     check.warn(importable)
#   error: command '/usr/bin/gcc' failed with exit code 1
#   ----------------------------------------
#   ERROR: Failed building wheel for ibm-db
# Failed to build ibm-db
# ERROR: Could not build wheels for ibm-db which use PEP 517 and cannot be installed directly
# Requirement already satisfied: ipython-sql in /Users/marcinszyprowski/opt/anaconda3/lib/python3.8/site-packages (0.4.0)
# Requirement already satisfied: prettytable<1 in /Users/marcinszyprowski/opt/anaconda3/lib/python3.8/site-packages (from ipython-sql) (0.7.2)
# Requirement already satisfied: sqlalchemy>=0.6.7 in /Users/marcinszyprowski/opt/anaconda3/lib/python3.8/site-packages (from ipython-sql) (1.3.9)
# Requirement already satisfied: ipython-genutils>=0.1.0 in /Users/marcinszyprowski/opt/anaconda3/lib/python3.8/site-packages (from ipython-sql) (0.2.0)
# Requirement already satisfied: ipython>=1.0 in /Users/marcinszyprowski/opt/anaconda3/lib/python3.8/site-packages (from ipython-sql) (7.22.0)
# Requirement already satisfied: six in /Users/marcinszyprowski/opt/anaconda3/lib/python3.8/site-packages (from ipython-sql) (1.15.0)
# Requirement already satisfied: sqlparse in /Users/marcinszyprowski/opt/anaconda3/lib/python3.8/site-packages (from ipython-sql) (0.4.2)
# Requirement already satisfied: pickleshare in /Users/marcinszyprowski/opt/anaconda3/lib/python3.8/site-packages (from ipython>=1.0->ipython-sql) (0.7.5)
# Requirement already satisfied: backcall in /Users/marcinszyprowski/opt/anaconda3/lib/python3.8/site-packages (from ipython>=1.0->ipython-sql) (0.2.0)
# Requirement already satisfied: setuptools>=18.5 in /Users/marcinszyprowski/opt/anaconda3/lib/python3.8/site-packages (from ipython>=1.0->ipython-sql) (52.0.0.post20210125)
# Requirement already satisfied: pexpect>4.3 in /Users/marcinszyprowski/opt/anaconda3/lib/python3.8/site-packages (from ipython>=1.0->ipython-sql) (4.8.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/marcinszyprowski/opt/anaconda3/lib/python3.8/site-packages (from ipython>=1.0->ipython-sql) (3.0.17)
# Requirement already satisfied: jedi>=0.16 in /Users/marcinszyprowski/opt/anaconda3/lib/python3.8/site-packages (from ipython>=1.0->ipython-sql) (0.17.2)
# Requirement already satisfied: pygments in /Users/marcinszyprowski/opt/anaconda3/lib/python3.8/site-packages (from ipython>=1.0->ipython-sql) (2.8.1)
# Requirement already satisfied: appnope in /Users/marcinszyprowski/opt/anaconda3/lib/python3.8/site-packages (from ipython>=1.0->ipython-sql) (0.1.2)
# Requirement already satisfied: decorator in /Users/marcinszyprowski/opt/anaconda3/lib/python3.8/site-packages (from ipython>=1.0->ipython-sql) (5.0.6)
# Requirement already satisfied: traitlets>=4.2 in /Users/marcinszyprowski/opt/anaconda3/lib/python3.8/site-packages (from ipython>=1.0->ipython-sql) (5.0.5)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in /Users/marcinszyprowski/opt/anaconda3/lib/python3.8/site-packages (from jedi>=0.16->ipython>=1.0->ipython-sql) (0.7.0)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/marcinszyprowski/opt/anaconda3/lib/python3.8/site-packages (from pexpect>4.3->ipython>=1.0->ipython-sql) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/marcinszyprowski/opt/anaconda3/lib/python3.8/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=1.0->ipython-sql) (0.2.5)

# %% [markdown]
# ### Connect to the database
#
# Let us first load the SQL extension and establish a connection with the database

# %%
# %load_ext sql

# %% [markdown]
# **DB2 magic in case of old UI service credentials.**
#
# In the next cell enter your db2 connection string. Recall you created Service Credentials for your Db2 instance before. From the **uri** field of your Db2 service credentials copy everything after db2:// (except the double quote at the end) and paste it in the cell below after ibm_db_sa://
#
# <img src ="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/FinalModule_edX/images/URI.jpg">
#
# in the following format
#
# **%sql ibm_db_sa://my-username:my-password\@my-hostname:my-port/my-db-name**
#
# **DB2 magic in case of new UI service credentials.**
#
# <img src ="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_2/images/servicecredentials.png" width=600>
#
# *   Use the following format.
#
# *   Add security=SSL at the end
#
# **%sql ibm_db_sa://my-username:my-password\@my-hostname:my-port/my-db-name?security=SSL**

# %%
# %sql ibm_db_sa://3ece33f4/ZeZezB5TJ1NbwbmB@90b1b1bc-95da-4791-9723-e30cc81398c7.brt9d04f0cmqeb8u7740.databases.appdomain.cloud:32516/c6621900-8949-44aa-ae82-3c7a7bc3254e?security=SSL
# Out:
# Connection info needed in SQLAlchemy format, example:
#                postgresql://username:password@hostname/dbname
#                or an existing connection: dict_keys([])
# Can't load plugin: sqlalchemy.dialects:ibm_db_sa
# Connection info needed in SQLAlchemy format, example:
#                postgresql://username:password@hostname/dbname
#                or an existing connection: dict_keys([])

# %% [markdown]
# ## Tasks
#
# Now write and execute SQL queries to solve the assignment tasks.
#
# ### Task 1
#
# ##### Display the names of the unique launch sites  in the space mission

# %% [markdown]
# ### Task 2
#
# ##### Display 5 records where launch sites begin with the string 'CCA'

# %% [markdown]
# ### Task 3
#
# ##### Display the total payload mass carried by boosters launched by NASA (CRS)

# %% [markdown]
# ### Task 4
#
# ##### Display average payload mass carried by booster version F9 v1.1

# %% [markdown]
# ### Task 5
#
# ##### List the date when the first successful landing outcome in ground pad was acheived.
#
# *Hint:Use min function*

# %% [markdown]
# ### Task 6
#
# ##### List the names of the boosters which have success in drone ship and have payload mass greater than 4000 but less than 6000

# %% [markdown]
# ### Task 7
#
# ##### List the total number of successful and failure mission outcomes

# %% [markdown]
# ### Task 8
#
# ##### List the   names of the booster_versions which have carried the maximum payload mass. Use a subquery

# %% [markdown]
# ### Task 9
#
# ##### List the failed landing_outcomes in drone ship, their booster versions, and launch site names for in year 2015

# %% [markdown]
# ### Task 10
#
# ##### Rank the count of landing outcomes (such as Failure (drone ship) or Success (ground pad)) between the date 2010-06-04 and 2017-03-20, in descending order

# %% [markdown]
# ### Reference Links
#
# *   <a href ="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/Labs_Coursera_V5/labs/Lab%20-%20String%20Patterns%20-%20Sorting%20-%20Grouping/instructional-labs.md.html?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDS0321ENSkillsNetwork26802033-2022-01-01&origin=www.coursera.org">Hands-on Lab : String Patterns, Sorting and Grouping</a>
#
# *   <a  href="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/Labs_Coursera_V5/labs/Lab%20-%20Built-in%20functions%20/Hands-on_Lab__Built-in_Functions.md.html?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDS0321ENSkillsNetwork26802033-2022-01-01&origin=www.coursera.org">Hands-on Lab: Built-in functions</a>
#
# *   <a  href="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/Labs_Coursera_V5/labs/Lab%20-%20Sub-queries%20and%20Nested%20SELECTs%20/instructional-labs.md.html?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDS0321ENSkillsNetwork26802033-2022-01-01&origin=www.coursera.org">Hands-on Lab : Sub-queries and Nested SELECT Statements</a>
#
# *   <a href="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/Module%205/DB0201EN-Week3-1-3-SQLmagic.ipynb?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDS0321ENSkillsNetwork26802033-2022-01-01">Hands-on Tutorial: Accessing Databases with SQL magic</a>
#
# *   <a href= "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/Module%205/DB0201EN-Week3-1-4-Analyzing.ipynb?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDS0321ENSkillsNetwork26802033-2022-01-01">Hands-on Lab: Analyzing a real World Data Set</a>

# %% [markdown]
# ## Author(s)
#
# <h4> Lakshmi Holla </h4>

# %% [markdown]
# ## Other Contributors
#
# <h4> Rav Ahuja </h4>

# %% [markdown]
# ## Change log
#
# | Date       | Version | Changed by    | Change Description        |
# | ---------- | ------- | ------------- | ------------------------- |
# | 2021-10-12 | 0.4     | Lakshmi Holla | Changed markdown          |
# | 2021-08-24 | 0.3     | Lakshmi Holla | Added library update      |
# | 2021-07-09 | 0.2     | Lakshmi Holla | Changes made in magic sql |
# | 2021-05-20 | 0.1     | Lakshmi Holla | Created Initial Version   |

# %% [markdown]
# ## <h3 align="center"> © IBM Corporation 2021. All rights reserved. <h3/>
